# %% [markdown]
# <a href="https://colab.research.google.com/github/GundamYeti/MSDS462_Winter2020/blob/master/Matt_Cherry_Module3_API_Upload.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-cloud-vision
# Out:
# ...
#      |████████████████████████████████| 440kB 2.8MB/s
# ...

# %%
from google.cloud import vision

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import time
import matplotlib.pyplot as plt

import os
import io


from google.cloud import vision
from google.cloud import storage
from google.cloud.vision_v1 import enums
from google.cloud.vision_v1 import ImageAnnotatorClient
from google.cloud.vision_v1 import types
import os
import json

import os
from google.cloud import vision
from google.cloud.vision import types
from PIL import Image as Img, ImageDraw
from IPython.display import Image

# %%
from google.colab import drive
drive.mount('/content/drive')

os.environ["GOOGLE_APPLICATION_CREDENTIALS"]='/content/drive/My Drive/JSON_Keys/PhotoID.json'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from google.cloud import vision

client = vision.ImageAnnotatorClient()
image = vision.types.Image()

pic = '/content/drive/My Drive/Die_Hard/DH1.jpg'

image.source.image_uri = os.path.abspath("/content/drive/My Drive/Die_Hard/DH1.jpg")
response = client.face_detection(image=image)
print(f'File: {pic}')

likelihood = vision.enums.Likelihood(face.surprise_likelihood)

vertices = [f'({v.x},{v.y})' for v in face.bounding_poly.vertices]

print(f'Face surprised: {likelihood.name}')
print(f'Face bounds: {",".join(vertices)}')

Image("/content/drive/My Drive/Die_Hard/DH1.jpg", width=500, height=500)
# Out:
# File: /content/drive/My Drive/Die_Hard/DH1.jpg
# Face surprised: LIKELY
# Face bounds: (16,38),(323,38),(323,394),(16,394)

# %%
from google.cloud import vision

client = vision.ImageAnnotatorClient()
image = vision.types.Image()

pic = '/content/drive/My Drive/Die_Hard/DH2.jpg'


image.source.image_uri = os.path.abspath("/content/drive/My Drive/Die_Hard/DH2.jpg")
response = client.face_detection(image=image)
print(f'File: {pic}')

likelihood = vision.enums.Likelihood(face.surprise_likelihood)

vertices = [f'({v.x},{v.y})' for v in face.bounding_poly.vertices]

print(f'Face surprised: {likelihood.name}')
print(f'Face bounds: {",".join(vertices)}')

Image("/content/drive/My Drive/Die_Hard/DH2.jpg", width=500, height=500)
# Out:
# File: /content/drive/My Drive/Die_Hard/DH2.jpg
# Face surprised: LIKELY
# Face bounds: (16,38),(323,38),(323,394),(16,394)

# %%
from google.cloud import vision

client = vision.ImageAnnotatorClient()
image = vision.types.Image()

pic = '/content/drive/My Drive/Die_Hard/DH3.png'

image.source.image_uri = os.path.abspath("/content/drive/My Drive/Die_Hard/DH3.png")
response = client.face_detection(image=image)
print(f'File: {pic}')

likelihood = vision.enums.Likelihood(face.surprise_likelihood)

vertices = [f'({v.x},{v.y})' for v in face.bounding_poly.vertices]

print(f'Face surprised: {likelihood.name}')
print(f'Face bounds: {",".join(vertices)}')

Image("/content/drive/My Drive/Die_Hard/DH3.png", width=500, height=500)
# Out:
# File: /content/drive/My Drive/Die_Hard/DH3.png
# Face surprised: LIKELY
# Face bounds: (16,38),(323,38),(323,394),(16,394)
